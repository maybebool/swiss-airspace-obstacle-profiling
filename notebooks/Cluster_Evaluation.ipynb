# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score, silhouette_samples
import matplotlib.cm as cm

try:
    import hdbscan
except ImportError:
    print("Installing hdbscan...")
    import subprocess
    subprocess.check_call(['pip', 'install', 'hdbscan'])
    import hdbscan

sns.set_style('whitegrid')

# %% [markdown]
# ## 1. Load Grid Features

# %%
grid = pd.read_parquet('../data/processed/grid_features.parquet')
print(f"Loaded: {len(grid)} grid cells")

feature_cols = ['obstacle_count', 'height_mean', 'height_max', 'height_std',
                'elevation_mean', 'pct_linear', 'pct_vertical', 'pct_diversity',
                'pct_lighted', 'has_airport']

X = grid[feature_cols].copy()
X.head()
# Out:
# Loaded: 3976 grid cells
#    obstacle_count  height_mean  height_max  height_std  elevation_mean  \
# 0             1.0    36.000000        36.0    0.000000      552.500000
# 1             2.0    35.550000        43.0   10.535891      435.050000
# 2             2.0    49.550000        56.0    9.121677      540.250000
# 3             1.0    31.000000        31.0    0.000000      456.000000
# 4             3.0    32.766667        56.4   21.033862      497.366667
#
#    pct_linear  pct_vertical  pct_diversity  pct_lighted  has_airport
# 0       100.0           0.0            1.0        100.0          0.0
# 1       100.0           0.0            1.0          0.0          0.0
# 2       100.0           0.0            2.0          0.0          0.0
# 3       100.0           0.0            1.0          0.0          0.0
# 4       100.0           0.0            2.0          0.0          0.0
